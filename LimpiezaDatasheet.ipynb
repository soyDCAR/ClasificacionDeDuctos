# %% [markdown]
# # Remplazar doscs de imagen a img

# %%
import os
carpeta = 'img' 

if not os.path.isdir(carpeta):
    print(f"La carpeta '{carpeta}' no existe.")
else:
    archivos_encontrados = os.listdir(carpeta)
    print(f"Archivos encontrados en '{carpeta}': {archivos_encontrados}")
    
    renombrados = 0
    for nombre_archivo in archivos_encontrados:
        if nombre_archivo.lower().endswith('.png') and nombre_archivo.startswith('imagen'):
            nuevo_nombre = nombre_archivo.replace('imagen', 'img', 1)
            ruta_original = os.path.join(carpeta, nombre_archivo)
            ruta_nueva = os.path.join(carpeta, nuevo_nombre)

            os.rename(ruta_original, ruta_nueva)
            print(f'Renombrado: {nombre_archivo} -> {nuevo_nombre}')
            renombrados += 1

    if renombrados == 0:
        print("No se encontró ningún archivo .png que empiece con 'imagen'.")
    else:
        print(f"✅ Total de archivos renombrados: {renombrados}")
# Out:
# Archivos encontrados en 'img': ['.DS_Store', 'img000_d6_o4_v2.png', 'img001_d6_o2_v4.png', 'img002_d6_o0_v6.png', 'img003_d6_o0_v6.png', 'img004_d6_o4_v2.png', 'img005_d8_o7_v1.png', 'img006_d2_o2_v0.png', 'img007_d6_o3_v3.png', 'img008_d1_o1_v0.png', 'img009_d6_o2_v4.png', 'img010_d2_o1_v1.png', 'img011_d6_o2_v4.png', 'img012_d10_o2_v8.png', 'img013_d6_o2_v4.png', 'img014_d7_o2_v5.png', 'img015_d5_o3_v2.png', 'img016_d7_o5_v2.png', 'img017_d6_o0_v6.png', 'img018_d7_o6_v1.png', 'img019_d4_o3_v1.png', 'img020_d1_o1_v0.png', 'img021_d4_o3_v1.png', 'img022_d6_o4_v2.png', 'img023_d6_o5_v1.png', 'img024_d6_o5_v1.png', 'img025_d4_o2_v2.png', 'img026_d2_o2_v0.png', 'img027_d4_o4_v0.png', 'img028_d4_o4_v0.png', 'img029_d3_o2_v1.png', 'img030_d2_o1_v1.png', 'img031_d4_o2_v2.png', 'img032_d2_o2_v0.png', 'img033_d6_o2_v4.png', 'img034_d6_o6_v6.png', 'img035_d1_o1_v0.png', 'img036_d6_o4_v2.png', 'img037_d6_o4_v2.png', 'img038_d6_o0_v6.png', 'img039_d1_o0_v1.png', 'img040_d2_o1_v1.png', 'img041_d4_o3_v1.png', 'img042_d5_o1_v4.png', 'img043_d11_o3_v8.png', 'img044_d2_o1_v1.png', 'img045_d4_o2_v2.png', 'img046_d4_o1_v3.png', 'img047_d4_o3_v1.png', 'img048_d5_o1_v4.png', 'img049_d9_o3_v6.png', 'img050_d2_o1_v1.png', 'img051_d4_o2_v2.png', 'img052_d4_o1_v3.png', 'img053_d4_o4_v0.png', 'img054_d3_o2_v1.png', 'img055_d6_o4_v2.png', 'img056_d4_o2_v2.png', 'img057_d6_o2_v4.png', 'img058_d6_o1_v5.png', 'img059_d3_o2_v1.png', 'img060_d3_o3_v0.png', 'img061_d3_o2_v1.png', 'img062_d3_o3_v0.png', 'img063_d4_o4_v0.png', 'img064_d1_o1_v0.png', 'img065_d1_o1_v0.png', 'img066_d2_o2_v0.png', 'img067_d1_o1_v0.png', 'img068_d3_o2_v1.png', 'img069_d1_o1_v0.png', 'img070_d3_o3_v0.png', 'img071_d2_o2_v0.png', 'img072_d2_o2_v0.png', 'img073_d2_o2_v0.png', 'img074_d2_o2_v0.png', 'img075_d2_o2_v0.png', 'img076_d1_o1_v0.png', 'img077_d5_o3_v2.png', 'img078_d3_o3_v0.png', 'img079_d2_o2_v0.png', 'img080_d5_o5_v0.png', 'img081_d2_o2_v0.png', 'img082_d1_o1_v0.png', 'img083_d2_o2_v0.png', 'img084_d2_o2_v0.png', 'img085_d2_o2_v0.png', 'img086_d1_o1_v0.png', 'img087_d2_o2_v0.png', 'img088_d1_o1_v0.png', 'img089_d4_o3_v1.png', 'img090_d4_o3_v1.png', 'img091_d4_o3_v1.png', 'img092_d5_o2_v2.png', 'img093_d3_o2_v1.png', 'img094_d4_o4_v0.png', 'img095_d8_o8_v0.png', 'img096_d2_o2_v0.png', 'img097_d1_o1_v0.png', 'img098_d5_o5_v0.png', 'img099_d1_o1_v0.png', 'img100_d6_o3_v3.png', 'img101_d1_o1_v0.png', 'img102_d5_o4_v1.png', 'img103_d4_o2_v2.png', 'img104_d2_o1_v1.png', 'img105_d2_o2_v0.png', 'img106_d2_o2_v0.png', 'img107_d2_o1_v1.png', 'img108_d1_o1_v1.png', 'img109_d4_o2_v2.png', 'img110_d4_o3_v1.png', 'img111_d4_o3_v1.png', 'img112_d2_o1_v1.png', 'img113_d4_o3_v1.png', 'img114_d2_o2_v0.png', 'img115_d1_o1_v0.png', 'img116_d2_o1_v1.png', 'img117_d2_o2_v0.png', 'img118_d3_o2_v1.png', 'img119_d1_o1_v0.png', 'img120_d3_o2_v1.png', 'img121_d2_o0_v2.png', 'img122_d3_o1_v2.png', 'img123_d2_o1_v1.png', 'img124_d2_o1_v1.png', 'img125_d3_o2_v1.png', 'img126_d1_o1_v0.png', 'img127_d2_o2_v0.png', 'img128_d1_o1_v0.png', 'img129_d2_o2_v0.png', 'img130_d1_o1_v0.png', 'img131_d1_o1_v0.png', 'img132_d1_o1_v0.png', 'img133_d2_o2_v0.png', 'img134_d1_o1_v0.png', 'img135_d2_o2_v0.png', 'img136_d1_o1_v0.png', 'img137_d2_o2_v0.png', 'img138_d2_o2_v0.png', 'img139_d2_o2_v0.png', 'img140_d2_o2_v0.png', 'img141_d1_o1_v0.png', 'img142_d2_o2_v0.png', 'img143_d2_o2_v0.png', 'img144_d1_o1_v0.png', 'img145_d2_o2_v0.png', 'img146_d1_o1_v0.png', 'img147_d2_o2_v0.png', 'img148_d1_o1_v0.png', 'img149_d2_o2_v0.png', 'img150_d1_o1_v0.png', 'img151_d1_o1_v0.png', 'img152_d1_o1_v0.png', 'img153_d1_o1_v0.png', 'img154_d3_o3_v0.png', 'img155_d2_o2_v0.png', 'img156_d1_o1_v0.png', 'img157_d2_o2_v0.png', 'img158_d2_o2_v0.png', 'img159_d1_o1_v0.png', 'img160_d2_o2_v0.png', 'img161_d1_o1_v0.png', 'img162_d2_o2_v0.png', 'img163_d1_o1_v0.png', 'img164_d2_o2_v0.png', 'img165_d2_o1_v1.png', 'img166_d2_o2_v0.png', 'img167_d1_o1_v0.png', 'img168_d2_o2_v0.png', 'img169_d2_o2_v0.png', 'img170_d1_o1_v0.png', 'img171_d1_o1_v0.png ...
# No se encontró ningún archivo .png que empiece con 'imagen'.

# %% [markdown]
# # Conteo de archivos

# %%
import os
import re

carpeta = 'img'

patron = re.compile(r'^img(\d+)_d\d+_o\d+_v\d+\.(png|jpg|jpeg)$', re.IGNORECASE)

numeros_img = []

for archivo in os.listdir(carpeta):
    match = patron.match(archivo)
    if match:
        numero = int(match.group(1))
        numeros_img.append(numero)

# Set con todos los números esperados
esperados = set(range(490))
presentes = set(numeros_img)

faltantes = sorted(esperados - presentes)
duplicados = [num for num in numeros_img if numeros_img.count(num) > 1]

print(f'🔢 Total únicos encontrados: {len(presentes)}')
print(f'📛 Números faltantes en la secuencia (0–489): {faltantes}')

if duplicados:
    print(f'⚠️ Números duplicados: {sorted(set(duplicados))}')
# Out:
# 🔢 Total únicos encontrados: 836
# 📛 Números faltantes en la secuencia (0–489): []
# ⚠️ Números duplicados: [378]

# %% [markdown]
# # Cambiar ruta a minusculas

# %%
import os

carpeta = 'img'  # Cambia la ruta si es necesario

# Extensiones que queremos convertir a minúscula
extensiones = ['.PNG', '.JPG', '.JPEG']

# Recorremos los archivos en la carpeta
for archivo in os.listdir(carpeta):
    nombre_base, extension = os.path.splitext(archivo)
    if extension.upper() in extensiones:
        nueva_extension = extension.lower()
        nuevo_nombre = nombre_base + nueva_extension

        ruta_original = os.path.join(carpeta, archivo)
        ruta_nueva = os.path.join(carpeta, nuevo_nombre)

        os.rename(ruta_original, ruta_nueva)
        print(f'✅ Renombrado: {archivo} -> {nuevo_nombre}')
# Out:
# ✅ Renombrado: img000_d6_o4_v2.png -> img000_d6_o4_v2.png
# ✅ Renombrado: img001_d6_o2_v4.png -> img001_d6_o2_v4.png
# ✅ Renombrado: img002_d6_o0_v6.png -> img002_d6_o0_v6.png
# ✅ Renombrado: img003_d6_o0_v6.png -> img003_d6_o0_v6.png
# ✅ Renombrado: img004_d6_o4_v2.png -> img004_d6_o4_v2.png
# ✅ Renombrado: img005_d8_o7_v1.png -> img005_d8_o7_v1.png
# ✅ Renombrado: img006_d2_o2_v0.png -> img006_d2_o2_v0.png
# ✅ Renombrado: img007_d6_o3_v3.png -> img007_d6_o3_v3.png
# ✅ Renombrado: img008_d1_o1_v0.png -> img008_d1_o1_v0.png
# ✅ Renombrado: img009_d6_o2_v4.png -> img009_d6_o2_v4.png
# ✅ Renombrado: img010_d2_o1_v1.png -> img010_d2_o1_v1.png
# ✅ Renombrado: img011_d6_o2_v4.png -> img011_d6_o2_v4.png
# ✅ Renombrado: img012_d10_o2_v8.png -> img012_d10_o2_v8.png
# ✅ Renombrado: img013_d6_o2_v4.png -> img013_d6_o2_v4.png
# ✅ Renombrado: img014_d7_o2_v5.png -> img014_d7_o2_v5.png
# ✅ Renombrado: img015_d5_o3_v2.png -> img015_d5_o3_v2.png
# ✅ Renombrado: img016_d7_o5_v2.png -> img016_d7_o5_v2.png
# ✅ Renombrado: img017_d6_o0_v6.png -> img017_d6_o0_v6.png
# ✅ Renombrado: img018_d7_o6_v1.png -> img018_d7_o6_v1.png
# ✅ Renombrado: img019_d4_o3_v1.png -> img019_d4_o3_v1.png
# ✅ Renombrado: img020_d1_o1_v0.png -> img020_d1_o1_v0.png
# ✅ Renombrado: img021_d4_o3_v1.png -> img021_d4_o3_v1.png
# ✅ Renombrado: img022_d6_o4_v2.png -> img022_d6_o4_v2.png
# ✅ Renombrado: img023_d6_o5_v1.png -> img023_d6_o5_v1.png
# ✅ Renombrado: img024_d6_o5_v1.png -> img024_d6_o5_v1.png
# ✅ Renombrado: img025_d4_o2_v2.png -> img025_d4_o2_v2.png
# ✅ Renombrado: img026_d2_o2_v0.png -> img026_d2_o2_v0.png
# ✅ Renombrado: img027_d4_o4_v0.png -> img027_d4_o4_v0.png
# ✅ Renombrado: img028_d4_o4_v0.png -> img028_d4_o4_v0.png
# ✅ Renombrado: img029_d3_o2_v1.png -> img029_d3_o2_v1.png
# ✅ Renombrado: img030_d2_o1_v1.png -> img030_d2_o1_v1.png
# ✅ Renombrado: img031_d4_o2_v2.png -> img031_d4_o2_v2.png
# ✅ Renombrado: img032_d2_o2_v0.png -> img032_d2_o2_v0.png
# ✅ Renombrado: img033_d6_o2_v4.png -> img033_d6_o2_v4.png
# ✅ Renombrado: img034_d6_o6_v6.png -> img034_d6_o6_v6.png
# ✅ Renombrado: img035_d1_o1_v0.png -> img035_d1_o1_v0.png
# ✅ Renombrado: img036_d6_o4_v2.png -> img036_d6_o4_v2.png
# ✅ Renombrado: img037_d6_o4_v2.png -> img037_d6_o4_v2.png
# ✅ Renombrado: img038_d6_o0_v6.png -> img038_d6_o0_v6.png
# ✅ Renombrado: img039_d1_o0_v1.png -> img039_d1_o0_v1.png
# ✅ Renombrado: img040_d2_o1_v1.png -> img040_d2_o1_v1.png
# ✅ Renombrado: img041_d4_o3_v1.png -> img041_d4_o3_v1.png
# ✅ Renombrado: img042_d5_o1_v4.png -> img042_d5_o1_v4.png
# ✅ Renombrado: img043_d11_o3_v8.png -> img043_d11_o3_v8.png
# ✅ Renombrado: img044_d2_o1_v1.png -> img044_d2_o1_v1.png
# ✅ Renombrado: img045_d4_o2_v2.png -> img045_d4_o2_v2.png
# ✅ Renombrado: img046_d4_o1_v3.png -> img046_d4_o1_v3.png
# ✅ Renombrado: img047_d4_o3_v1.png -> img047_d4_o3_v1.png
# ✅ Renombrado: img048_d5_o1_v4.png -> img048_d5_o1_v4.png
# ✅ Renombrado: img049_d9_o3_v6.png -> img049_d9_o3_v6.png
# ✅ Renombrado: img050_d2_o1_v1.png -> img050_d2_o1_v1.png
# ✅ Renombrado: img051_d4_o2_v2.png -> img051_d4_o2_v2.png
# ✅ Renombrado: img052_d4_o1_v3.png -> img052_d4_o1_v3.png
# ✅ Renombrado: img053_d4_o4_v0.png -> img053_d4_o4_v0.png
# ✅ Renombrado: img054_d3_o2_v1.png -> img054_d3_o2_v1.png
# ✅ Renombrado: img055_d6_o4_v2.png -> img055_d6_o4_v2.png
# ✅ Renombrado: img056_d4_o2_v2.png -> img056_d4_o2_v2.png
# ✅ Renombrado: img057_d6_o2_v4.png -> img057_d6_o2_v4.png
# ✅ Renombrado: img058_d6_o1_v5.png -> img058_d6_o1_v5.png
# ✅ Renombrado: img059_d3_o2_v1.png -> img059_d3_o2_v1.png
# ✅ Renombrado: img060_d3_o3_v0.png -> img060_d3_o3_v0.png
# ✅ Renombrado: img061_d3_o2_v1.png -> img061_d3_o2_v1.png
# ✅ Renombrado: img062_d3_o3_v0.png -> img062_d3_o3_v0.png
# ✅ Renombrado: img063_d4_o4_v0.png -> img063_d4_o4_v0.png
# ✅ Renombrado: img064_d1_o1_v0.png -> img064_d1_o1_v0.png
# ✅ Renombrado: img065_d1_o1_v0.png -> img065_d1_o1_v0.png
# ✅ Renombrado: img066_d2_o2_v0.png -> img066_d2_o2_v0.png
# ✅ Renombrado: img067_d1_o1_v0.png -> img067_d1_o1_v0.png
# ✅ Renombrado: img068_d3_o2_v1.png -> img068_d3_o2_v1.png
# ✅ Renombrado: img069_d1_o1_v0.png -> img069_d1_o1_v0.png
# ✅ Renombrado: img070_d3_o3_v0.png -> img070_d3_o3_v0.png
# ✅ Renombrado: img071_d2_o2_v0.png -> img071_d2_o2_v0.png
# ✅ Renombrado: img072_d2_o2_v0.png -> img072_d2_o2_v0.png
# ✅ Renombrado: img073_d2_o2_v0.png -> img073_d2_o2_v0.png
# ✅ Renombrado: img074_d2_o2_v0.png -> img074_d2_o2_v0.png
# ✅ Renombrado: img075_d2_o2_v0.png -> img075_d2_o2_v0.png
# ✅ Renombrado: img076_d1_o1_v0.png -> img076_d1_o1_v0.png
# ✅ Renombrado: img077_d5_o3_v2.png -> img077_d5_o3_v2.png
# ✅ Renombrado: img078_d3_o3_v0.png -> img078_d3_o3_v0.png
# ✅ Renombrado: img079_d2_o2_v0.png -> img079_d2_o2_v0.png
# ✅ Renombrado: img080_d5_o5_v0.png -> img080_d5_o5_v0.png
# ✅ Renombrado: img081_d2_o2_v0.png -> img081_d2_o2_v0.png
# ✅ Renombrado: img082_d1_o1_v0.png -> img082_d1_o1_v0.png
# ✅ Renombrado: img083_d2_o2_v0.png -> img083_d2_o2_v0.png
# ✅ Renombrado: img084_d2_o2_v0.png -> img084_d2_o2_v0.png
# ✅ Renombrado: img085_d2_o2_v0.png -> img085_d2_o2_v0.png
# ✅ Renombrado: img086_d1_o1_v0.png -> img086_d1_o1_v0.png
# ✅ Renombrado: img087_d2_o2_v0.png -> img087_d2_o2_v0.png
# ✅ Renombrado: img088_d1_o1_v0.png -> img088_d1_o1_v0.png
# ✅ Renombrado: img089_d4_o3_v1.png -> img089_d4_o3_v1.png
# ✅ Renombrado: img090_d4_o3_v1.png -> img090_d4_o3_v1.png
# ✅ Renombrado: img091_d4_o3_v1.png -> img091_d4_o3_v1.png
# ✅ Renombrado: img092_d5_o2_v2.png -> img092_d5_o2_v2.png
# ✅ Renombrado: img093_d3_o2_v1.png -> img093_d3_o2_v1.png
# ✅ Renombrado: img094_d4_o4_v0.png -> img094_d4_o4_v0.png
# ✅ Renombrado: img095_d8_o8_v0.png -> img095_d8_o8_v0.png
# ✅ Renombrado: img096_d2_o2_v0.png -> img096_d2_o2_v0.png
# ✅ Renombrado: img097_d1_o1_v0.png -> img097_d1_o1_v0.png
# ✅ Renombrado: img098_d5_o5_v0.png -> img098_d5_o5_v0.png
# ✅ Renombrado: img099_d1_o1_v0.png -> img099_d1_o1_v0.png
# ✅ Renombrado: img100_d6_o3_v3.png -> img100_d6_o3_v3.png
# ✅ Renombrado: img101_d1_o1_v0.png -> img101_d1_o1_v0.png
# ✅ Renombrado: img102_d5_o4_v1.png -> img102_d5_o4_v1.png
# ✅ Renombrado: img103_d4_o2_v2.png -> img103_d4_o2_v2.png
# ✅ Renombrado: img104_d2_o1_v1.png -> img104_d2_o1_v1.png
# ✅ Renombrado: img105_d2_o2_v0.png -> img105_d2_o2_v0.png
# ✅ Renombrado: img106_d2_o2_v0.png -> img106_d2_o2_v0.png
# ✅ Renombrado: img107_d2_o1_v1.png -> img107_d2_o1_v1.png
# ✅ Renombrado: img108_d1_o1_v1.png -> img108_d1_o1_v1.png
# ✅ Renombrado: img109_d4_o2_v2.png -> img109_d4_o2_v2.png
# ✅ Renombrado: img110_d4_o3_v1.png -> img110_d4_o3_v1.png
# ✅ Renombrado: img111_d4_o3_v1.png -> img111_d4_o3_v1.png
# ✅ Renombrado: img112_d2_o1_v1.png -> img112_d2_o1_v1.png
# ✅ Renombrado: img113_d4_o3_v1.png -> img113_d4_o3_v1.png
# ✅ Renombrado: img114_d2_o2_v0.png -> img114_d2_o2_v0.png
# ✅ Renombrado: img115_d1_o1_v0.png -> img115_d1_o1_v0.png
# ✅ Renombrado: img116_d2_o1_v1.png -> img116_d2_o1_v1.png
# ✅ Renombrado: img117_d2_o2_v0.png -> img117_d2_o2_v0.png
# ✅ Renombrado: img118_d3_o2_v1.png -> img118_d3_o2_v1.png
# ✅ Renombrado: img119_d1_o1_v0.png -> img119_d1_o1_v0.png
# ✅ Renombrado: img120_d3_o2_v1.png -> img120_d3_o2_v1.png
# ✅ Renombrado: img121_d2_o0_v2.png -> img121_d2_o0_v2.png
# ✅ Renombrado: img122_d3_o1_v2.png -> img122_d3_o1_v2.png
# ✅ Renombrado: img123_d2_o1_v1.png -> img123_d2_o1_v1.png
# ✅ Renombrado: img124_d2_o1_v1.png -> img124_d2_o1_v1.png
# ✅ Renombrado: img125_d3_o2_v1.png -> img125_d3_o2_v1.png
# ✅ Renombrado: img126_d1_o1_v0.png -> img126_d1_o1_v0.png
# ✅ Renombrado: img127_d2_o2_v0.png -> img127_d2_o2_v0.png
# ✅ Renombrado: img128_d1_o1_v0.png -> img128_d1_o1_v0.png
# ✅ Renombrado: img129_d2_o2_v0.png -> img129_d2_o2_v0.png
# ✅ Renombrado: img130_d1_o1_v0.png -> img130_d1_o1_v0.png
# ✅ Renombrado: img131_d1_o1_v0.png -> img131_d1_o1_v0.png
# ✅ Renombrado: img132_d1_o1_v0.png -> img132_d1_o1_v0.png
# ✅ Renombrado: img133_d2_o2_v0.png -> img133_d2_o2_v0.png
# ✅ Renombrado: img134_d1_o1_v0.png -> img134_d1_o1_v0.png
# ✅ Renombrado: img135_d2_o2_v0.png -> img135_d2_o2_v0.png
# ✅ Renombrado: img136_d1_o1_v0.png -> img136_d1_o1_v0.png
# ✅ Renombrado: img137_d2_o2_v0.png -> img137_d2_o2_v0.png
# ✅ Renombrado: img138_d2_o2_v0.png -> img138_d2_o2_v0.png
# ✅ Renombrado: img139_d2_o2_v0.png -> img139_d2_o2_v0.png
# ✅ Renombrado: img140_d2_o2_v0.png -> img140_d2_o2_v0.png
# ✅ Renombrado: img141_d1_o1_v0.png -> img141_d1_o1_v0.png
# ✅ Renombrado: img142_d2_o2_v0.png -> img142_d2_o2_v0.png
# ✅ Renombrado: img143_d2_o2_v0.png -> img143_d2_o2_v0.png
# ✅ Renombrado: img144_d1_o1_v0.png -> img144_d1_o1_v0.png
# ✅ Renombrado: img145_d2_o2_v0.png -> img145_d2_o2_v0.png
# ✅ Renombrado: img146_d1_o1_v0.png -> img146_d1_o1_v0.png
# ✅ Renombrado: img147_d2_o2_v0.png -> img147_d2_o2_v0.png
# ✅ Renombrado: img148_d1_o1_v0.png -> img148_d1_o1_v0.png
# ✅ Renombrado: img149_d2_o2_v0.png -> img149_d2_o2_v0.png
# ✅ Renombrado: img150_d1_o1_v0.png -> img150_d1_o1_v0.png
# ✅ Renombrado: img151_d1_o1_v0.png -> img151_d1_o1_v0.png
# ✅ Renombrado: img152_d1_o1_v0.png -> img152_d1_o1_v0.png
# ✅ Renombrado: img153_d1_o1_v0.png -> img153_d1_o1_v0.png
# ✅ Renombrado: img154_d3_o3_v0.png -> img154_d3_o3_v0.png
# ✅ Renombrado: img155_d2_o2_v0.png -> img155_d2_o2_v0.png
# ✅ Renombrado: img156_d1_o1_v0.png -> img156_d1_o1_v0.png
# ✅ Renombrado: img157_d2_o2_v0.png -> img157_d2_o2_v0.png
# ✅ Renombrado: img158_d2_o2_v0.png -> img158_d2_o2_v0.png
# ✅ Renombrado: img159_d1_o1_v0.png -> img159_d1_o1_v0.png
# ✅ Renombrado: img160_d2_o2_v0.png -> img160_d2_o2_v0.png
# ✅ Renombrado: img161_d1_o1_v0.png -> img161_d1_o1_v0.png
# ✅ Renombrado: img162_d2_o2_v0.png -> img162_d2_o2_v0.png
# ✅ Renombrado: img163_d1_o1_v0.png -> img163_d1_o1_v0.png
# ✅ Renombrado: img164_d2_o2_v0.png -> img164_d2_o2_v0.png
# ✅ Renombrado: img165_d2_o1_v1.png -> img165_d2_o1_v1.png
# ✅ Renombrado: img166_d2_o2_v0.png -> img166_d2_o2_v0.png
# ✅ Renombrado: img167_d1_o1_v0.png -> img167_d1_o1_v0.png
# ✅ Renombrado: img168_d2_o2_v0.png -> img168_d2_o2_v0.png
# ✅ Renombrado: img169_d2_o2_v0.png -> img169_d2_o2_v0.png
# ✅ Renombrado: img170_d1_o1_v0.png -> img170_d1_o1_v0.png
# ✅ Renombrado: img171_d1_o1_v0.png -> img171_d1_o1_v0.png
# ✅ Renombrado: img172_d2_o2_v0.png -> img172_d2_o2_v0.png
# ✅ Renombrado: img173_d4_o3_v1.png -> img173_d4_o3_v1.png
# ✅ Renombrado: img174_d1_o1_v0.png -> img174_d1_o1_v0.png
# ✅ Renombrado: img175_d2_o2_v0.png -> img175_d2_o2_v0.png
# ✅ Renombrado: img176_d5_o5_v0.png -> img176_d5_o5_v0.png
# ✅ Renombrado: img177_d1_o1_v0.png -> img177_d1_o1_v0.png
# ✅ Renombrado: img178_d4_o4_v0.png -> img178_d4_o4_v0.png
# ✅ Renombrado: img179_d1_o1_v0.png -> img179_d1_o1_v0.png
# ✅ Renombrado: img180_d5_o5_v0.png -> img180_d5_o5_v0.png
# ✅ Renombrado: img181_d1_o1_v0.png -> img181_d1_o1_v0.png
# ✅ Renombrado: img182_d2_o2_v0.png -> img182_d2_o2_v0.png
# ✅ Renombrado: img183_d3_o3_v0.png -> img183_d3_o3_v0.png
# ✅ Renombrado: img184_d2_o2_v0.png -> img184_d2_o2_v0.png
# ✅ Renombrado: img185_d2_o2_v0.png -> img185_d2_o2_v0.png
# ✅ Renombrado: img186_d3_o2_v1.png -> img186_d3_o2_v1.png
# ✅ Renombrado: img187_d5_o5_v0.png -> img187_d5_o5_v0.png
# ✅ Renombrado: img188_d5_o5_v0.png -> img188_d5_o5_v0.png
# ✅ Renombrado: img189_d5_o5_v0.png -> img189_d5_o5_v0.png
# ✅ Renombrado: img190_d6_o6_v0.png -> img190_d6_o6_v0.png
# ✅ Renombrado: img191_d3_o3_v0.png -> img191_d3_o3_v0.png
# ✅ Renombrado: img192_d2_o1_v1.png -> img192_d2_o1_v1.png
# ✅ Renombrado: img193_d5_o5_v0.png -> img193_d5_o5_v0.png
# ✅ Renombrado: img194_d5_o5_v0.png -> img194_d5_o5_v0.png
# ✅ Renombrado: img195_d1_o1_v0.png -> img195_d1_o1_v0.png
# ✅ Renombrado: img196_d3_o3_v0.png -> img196_d3_o3_v0.png
# ✅ Renombrado: img197_d1_o1_v0.png -> img197_d1_o1_v0.png
# ✅ Renombrado: img198_d5_o5_v0.png -> img198_d5_o5_v0.png
# ✅ Renombrado: img199_d1_o1_v0.png -> img199_d1_o1_v0.png
# ✅ Renombrado: img200_d2_o2_v0.png -> img200_d2_o2_v0.png
# ✅ Renombrado: img201_d6_o6_v0.png -> img201_d6_o6_v0.png
# ✅ Renombrado: img202_d1_o0_v1.png -> img202_d1_o0_v1.png
# ✅ Renombrado: img203_d2_o1_v1.png -> img203_d2_o1_v1.png
# ✅ Renombrado: img204_d13_o12_v1.png -> img204_d13_o12_v1.png
# ✅ Renombrado: img205_d1_o1_v0.png -> img205_d1_o1_v0.png
# ✅ Renombrado: img206_d1_o1_v0.png -> img206_d1_o1_v0.png
# ✅ Renombrado: img207_d9_o5_v4.png -> img207_d9_o5_v4.png
# ✅ Renombrado: img208_d4_o3_v1.png -> img208_d4_o3_v1.png
# ✅ Renombrado: img209_d4_o3_v1.png -> img209_d4_o3_v1.png
# ✅ Renombrado: img210_d1_o1_v0.png -> img210_d1_o1_v0.png
# ✅ Renombrado: img211_d1_o1_v0.png -> img211_d1_o1_v0.png
# ✅ Renombrado: img212_d2_o2_v0.png -> img212_d2_o2_v0.png
# ✅ Renombrado: img213_d4_o2_v2.png -> img213_d4_o2_v2.png
# ✅ Renombrado: img214_d2_o2_v0.png -> img214_d2_o2_v0.png
# ✅ Renombrado: img215_d3_o1_v2.png -> img215_d3_o1_v2.png
# ✅ Renombrado: img216_d1_o1_v0.png -> img216_d1_o1_v0.png
# ✅ Renombrado: img217_d1_o1_v0.png -> img217_d1_o1_v0.png
# ✅ Renombrado: img218_d3_o1_v2.png -> img218_d3_o1_v2.png
# ✅ Renombrado: img219_d2_o2_v0.png -> img219_d2_o2_v0.png
# ✅ Renombrado: img220_d1_o1_v0.png -> img220_d1_o1_v0.png
# ✅ Renombrado: img221_d4_o4_v0.png -> img221_d4_o4_v0.png
# ✅ Renombrado: img222_d2_o2_v0.png -> img222_d2_o2_v0.png
# ✅ Renombrado: img223_d3_o2_v1.png -> img223_d3_o2_v1.png
# ✅ Renombrado: img224_d3_o2_v1.png -> img224_d3_o2_v1.png
# ✅ Renombrado: img225_d3_o2_v1.png -> img225_d3_o2_v1.png
# ✅ Renombrado: img226_d2_o2_v0.png -> img226_d2_o2_v0.png
# ✅ Renombrado: img227_d3_o2_v1.png -> img227_d3_o2_v1.png
# ✅ Renombrado: img228_d1_o1_v0.png -> img228_d1_o1_v0.png
# ✅ Renombrado: img229_d1_o1_v0.png -> img229_d1_o1_v0.png
# ✅ Renombrado: img230_d9_o6_v3.png -> img230_d9_o6_v3.png
# ✅ Renombrado: img231_d2_o2_v0.png -> img231_d2_o2_v0.png
# ✅ Renombrado: img232_d2_o2_v1.png -> img232_d2_o2_v1.png
# ✅ Renombrado: img233_d1_o1_v0.png -> img233_d1_o1_v0.png
# ✅ Renombrado: img234_d2_o2_v0.png -> img234_d2_o2_v0.png
# ✅ Renombrado: img235_d1_o1_v0.png -> img235_d1_o1_v0.png
# ✅ Renombrado: img236_d2_o2_v0.png -> img236_d2_o2_v0.png
# ✅ Renombrado: img237_d3_o2_v1.png -> img237_d3_o2_v1.png
# ✅ Renombrado: img238_d3_o3_v0.png -> img238_d3_o3_v0.png
# ✅ Renombrado: img239_d3_o3_v0.png -> img239_d3_o3_v0.png
# ✅ Renombrado: img240_d6_o5_v1.png -> img240_d6_o5_v1.png
# ✅ Renombrado: img241_d2_o2_v0.png -> img241_d2_o2_v0.png
# ✅ Renombrado: img242_d4_o4_v0.png -> img242_d4_o4_v0.png
# ✅ Renombrado: img243_d4_o4_v0.png -> img243_d4_o4_v0.png
# ✅ Renombrado: img244_d1_o1_v0.png -> img244_d1_o1_v0.png
# ✅ Renombrado: img245_d5_o5_v0.png -> img245_d5_o5_v0.png
# ✅ Renombrado: img246_d2_o2_v0.png -> img246_d2_o2_v0.png
# ✅ Renombrado: img247_d4_o4_v0.png -> img247_d4_o4_v0.png
# ✅ Renombrado: img248_d1_o1_v0.png -> img248_d1_o1_v0.png
# ✅ Renombrado: img249_d1_o1_v0.png -> img249_d1_o1_v0.png
# ✅ Renombrado: img250_d2_o2_v0.png -> img250_d2_o2_v0.png
# ✅ Renombrado: img251_d2_o2_v0.png -> img251_d2_o2_v0.png
# ✅ Renombrado: img252_d4_o4_v0.png -> img252_d4_o4_v0.png
# ✅ Renombrado: img253_d1_o1_v0.png -> img253_d1_o1_v0.png
# ✅ Renombrado: img254_d4_o4_v0.png -> img254_d4_o4_v0.png
# ✅ Renombrado: img255_d4_o4_v0.png -> img255_d4_o4_v0.png
# ✅ Renombrado: img256_d4_o3_v1.png -> img256_d4_o3_v1.png
# ✅ Renombrado: img257_d4_o4_v0.png -> img257_d4_o4_v0.png
# ✅ Renombrado: img258_d4_o4_v0.png -> img258_d4_o4_v0.png
# ✅ Renombrado: img259_d1_o1_v0.png -> img259_d1_o1_v0.png
# ✅ Renombrado: img260_d3_o2_v1.png -> img260_d3_o2_v1.png
# ✅ Renombrado: img261_d1_o1_v0.png -> img261_d1_o1_v0.png
# ✅ Renombrado: img262_d7_o7_v0.png -> img262_d7_o7_v0.png
# ✅ Renombrado: img263_d3_o3_v0.png -> img263_d3_o3_v0.png
# ✅ Renombrado: img264_d5_o5_v0.png -> img264_d5_o5_v0.png
# ✅ Renombrado: img265_d3_o3_v0.png -> img265_d3_o3_v0.png
# ✅ Renombrado: img266_d5_o5_v0.png -> img266_d5_o5_v0.png
# ✅ Renombrado: img267_d5_o5_v0.png -> img267_d5_o5_v0.png
# ✅ Renombrado: img268_d5_o5_v0.png -> img268_d5_o5_v0.png
# ✅ Renombrado: img269_d5_o5_v0.png -> img269_d5_o5_v0.png
# ✅ Renombrado: img270_d6_o6_v0.png -> img270_d6_o6_v0.png
# ✅ Renombrado: img271_d2_o2_v0.png -> img271_d2_o2_v0.png
# ✅ Renombrado: img272_d2_o2_v0.png -> img272_d2_o2_v0.png
# ✅ Renombrado: img273_d4_o4_v0.png -> img273_d4_o4_v0.png
# ✅ Renombrado: img274_d3_o3_v0.png -> img274_d3_o3_v0.png
# ✅ Renombrado: img275_d4_o4_v0.png -> img275_d4_o4_v0.png
# ✅ Renombrado: img276_d3_o3_v0.png -> img276_d3_o3_v0.png
# ✅ Renombrado: img277_d1_o1_v0.png -> img277_d1_o1_v0.png
# ✅ Renombrado: img278_d2_o2_v0.png -> img278_d2_o2_v0.png
# ✅ Renombrado: img279_d1_o1_v0.png -> img279_d1_o1_v0.png
# ✅ Renombrado: img280_d6_o6_v0.png -> img280_d6_o6_v0.png
# ✅ Renombrado: img281_d1_o1_v0.png -> img281_d1_o1_v0.png
# ✅ Renombrado: img282_d1_o1_v0.png -> img282_d1_o1_v0.png
# ✅ Renombrado: img283_d5_o5_v0.png -> img283_d5_o5_v0.png
# ✅ Renombrado: img284_d7_o7_v0.png -> img284_d7_o7_v0.png
# ✅ Renombrado: img285_d2_o2_v0.png -> img285_d2_o2_v0.png
# ✅ Renombrado: img286_d4_o4_v0.png -> img286_d4_o4_v0.png
# ✅ Renombrado: img287_d4_o4_v0.png -> img287_d4_o4_v0.png
# ✅ Renombrado: img288_d1_o1_v0.png -> img288_d1_o1_v0.png
# ✅ Renombrado: img289_d3_o3_v0.png -> img289_d3_o3_v0.png
# ✅ Renombrado: img290_d1_o1_v0.png -> img290_d1_o1_v0.png
# ✅ Renombrado: img291_d4_o4_v0.png -> img291_d4_o4_v0.png
# ✅ Renombrado: img292_d4_o4_v0.png -> img292_d4_o4_v0.png
# ✅ Renombrado: img293_d7_o7_v0.png -> img293_d7_o7_v0.png
# ✅ Renombrado: img294_d1_o1_v0.png -> img294_d1_o1_v0.png
# ✅ Renombrado: img295_d5_o5_v0.png -> img295_d5_o5_v0.png
# ✅ Renombrado: img296_d6_o6_v0.png -> img296_d6_o6_v0.png
# ✅ Renombrado: img297_d5_o5_v0.png -> img297_d5_o5_v0.png
# ✅ Renombrado: img298_d5_o5_v0.png -> img298_d5_o5_v0.png
# ✅ Renombrado: img299_d1_o0_v1.png -> img299_d1_o0_v1.png
# ✅ Renombrado: img300_d5_o5_v0.png -> img300_d5_o5_v0.png
# ✅ Renombrado: img301_d5_o5_v0.png -> img301_d5_o5_v0.png
# ✅ Renombrado: img302_d5_o5_v0.png -> img302_d5_o5_v0.png
# ✅ Renombrado: img303_d4_o3_v1.png -> img303_d4_o3_v1.png
# ✅ Renombrado: img304_d6_o6_v0.png -> img304_d6_o6_v0.png
# ✅ Renombrado: img305_d2_o2_v0.png -> img305_d2_o2_v0.png
# ✅ Renombrado: img306_d5_o5_v0.png -> img306_d5_o5_v0.png
# ✅ Renombrado: img307_d1_o1_v0.png -> img307_d1_o1_v0.png
# ✅ Renombrado: img308_d1_o1_v0.png -> img308_d1_o1_v0.png
# ✅ Renombrado: img309_d5_o4_v1.png -> img309_d5_o4_v1.png
# ✅ Renombrado: img310_d2_o2_v0.png -> img310_d2_o2_v0.png
# ✅ Renombrado: img311_d2_o2_v0.png -> img311_d2_o2_v0.png
# ✅ Renombrado: img312_d1_o1_v0.png -> img312_d1_o1_v0.png
# ✅ Renombrado: img313_d2_o2_v0.png -> img313_d2_o2_v0.png
# ✅ Renombrado: img314_d2_o2_v0.png -> img314_d2_o2_v0.png
# ✅ Renombrado: img315_d1_o1_v0.png -> img315_d1_o1_v0.png
# ✅ Renombrado: img316_d1_o1_v0.png -> img316_d1_o1_v0.png
# ✅ Renombrado: img317_d3_o3_v0.png -> img317_d3_o3_v0.png
# ✅ Renombrado: img318_d3_o2_v1.png -> img318_d3_o2_v1.png
# ✅ Renombrado: img319_d1_o1_v0.png -> img319_d1_o1_v0.png
# ✅ Renombrado: img320_d1_o1_v0.png -> img320_d1_o1_v0.png
# ✅ Renombrado: img321_d1_o1_v0.png -> img321_d1_o1_v0.png
# ✅ Renombrado: img322_d4_o4_v0.png -> img322_d4_o4_v0.png
# ✅ Renombrado: img323_d6_o6_v0.png -> img323_d6_o6_v0.png
# ✅ Renombrado: img324_d4_o4_v0.png -> img324_d4_o4_v0.png
# ✅ Renombrado: img325_d3_o3_v0.png -> img325_d3_o3_v0.png
# ✅ Renombrado: img326_d2_o2_v0.png -> img326_d2_o2_v0.png
# ✅ Renombrado: img327_d2_o2_v0.png -> img327_d2_o2_v0.png
# ✅ Renombrado: img328_d1_o1_v0.png -> img328_d1_o1_v0.png
# ✅ Renombrado: img329_d2_o2_v0.png -> img329_d2_o2_v0.png
# ✅ Renombrado: img330_d1_o1_v0.png -> img330_d1_o1_v0.png
# ✅ Renombrado: img331_d3_o3_v0.png -> img331_d3_o3_v0.png
# ✅ Renombrado: img332_d2_o2_v0.png -> img332_d2_o2_v0.png
# ✅ Renombrado: img333_d1_o1_v0.png -> img333_d1_o1_v0.png
# ✅ Renombrado: img334_d1_o1_v0.png -> img334_d1_o1_v0.png
# ✅ Renombrado: img335_d3_o2_v1.png -> img335_d3_o2_v1.png
# ✅ Renombrado: img336_d1_o1_v0.png -> img336_d1_o1_v0.png
# ✅ Renombrado: img337_d2_o2_v0.png -> img337_d2_o2_v0.png
# ✅ Renombrado: img338_d1_o1_v0.png -> img338_d1_o1_v0.png
# ✅ Renombrado: img339_d1_o1_v0.png -> img339_d1_o1_v0.png
# ✅ Renombrado: img340_d4_o3_v1.png -> img340_d4_o3_v1.png
# ✅ Renombrado: img341_d2_o1_v1.png -> img341_d2_o1_v1.png
# ✅ Renombrado: img342_d3_o2_v1.png -> img342_d3_o2_v1.png
# ✅ Renombrado: img343_d1_o1_v0.png -> img343_d1_o1_v0.png
# ✅ Renombrado: img344_d1_o1_v0.png -> img344_d1_o1_v0.png
# ✅ Renombrado: img345_d1_o1_v0.png -> img345_d1_o1_v0.png
# ✅ Renombrado: img346_d5_o5_v0.png -> img346_d5_o5_v0.png
# ✅ Renombrado: img347_d2_o2_v0.png -> img347_d2_o2_v0.png
# ✅ Renombrado: img348_d5_o4_v1.png -> img348_d5_o4_v1.png
# ✅ Renombrado: img349_d6_o2_v4.png -> img349_d6_o2_v4.png
# ✅ Renombrado: img350_d4_o1_v3.png -> img350_d4_o1_v3.png
# ✅ Renombrado: img351_d4_o3_v1.png -> img351_d4_o3_v1.png
# ✅ Renombrado: img352_d6_o0_v6.png -> img352_d6_o0_v6.png
# ✅ Renombrado: img353_d3_o1_v2.png -> img353_d3_o1_v2.png
# ✅ Renombrado: img354_d4_o2_v2.png -> img354_d4_o2_v2.png
# ✅ Renombrado: img355_d4_o4_v0.png -> img355_d4_o4_v0.png
# ✅ Renombrado: img356_d1_o1_v0.png -> img356_d1_o1_v0.png
# ✅ Renombrado: img357_d2_o2_v0.png -> img357_d2_o2_v0.png
# ✅ Renombrado: img358_d2_o2_v0.png -> img358_d2_o2_v0.png
# ✅ Renombrado: img359_d2_o1_v1.png -> img359_d2_o1_v1.png
# ✅ Renombrado: img360_d4_o4_v0.png -> img360_d4_o4_v0.png
# ✅ Renombrado: img361_d3_o3_v0.png -> img361_d3_o3_v0.png
# ✅ Renombrado: img362_d4_o4_v0.png -> img362_d4_o4_v0.png
# ✅ Renombrado: img363_d1_o1_v0.png -> img363_d1_o1_v0.png
# ✅ Renombrado: img364_d1_o1_v0.png -> img364_d1_o1_v0.png
# ✅ Renombrado: img365_d1_o1_v0.png -> img365_d1_o1_v0.png
# ✅ Renombrado: img366_d1_o1_v0.png -> img366_d1_o1_v0.png
# ✅ Renombrado: img367_d1_o1_v0.png -> img367_d1_o1_v0.png
# ✅ Renombrado: img368_d1_o1_v0.png -> img368_d1_o1_v0.png
# ✅ Renombrado: img369_d1_o1_v0.png -> img369_d1_o1_v0.png
# ✅ Renombrado: img370_d1_o1_v0.png -> img370_d1_o1_v0.png
# ✅ Renombrado: img371_d1_o1_v0.png -> img371_d1_o1_v0.png
# ✅ Renombrado: img372_d1_o1_v0.png -> img372_d1_o1_v0.png
# ✅ Renombrado: img373_d1_o1_v0.png -> img373_d1_o1_v0.png
# ✅ Renombrado: img374_d1_o1_v0.png -> img374_d1_o1_v0.png
# ✅ Renombrado: img375_d1_o0_v1.png -> img375_d1_o0_v1.png
# ✅ Renombrado: img376_d4_o3_v1.png -> img376_d4_o3_v1.png
# ✅ Renombrado: img377_d4_o3_v1.png -> img377_d4_o3_v1.png
# ✅ Renombrado: img378_d1_o0_v1.png -> img378_d1_o0_v1.png
# ✅ Renombrado: img378_d1_o1_v0.png -> img378_d1_o1_v0.png
# ✅ Renombrado: img379_d1_o1_v0.png -> img379_d1_o1_v0.png
# ✅ Renombrado: img380_d1_o1_v0.png -> img380_d1_o1_v0.png
# ✅ Renombrado: img381_d1_o1_v0.png -> img381_d1_o1_v0.png
# ✅ Renombrado: img382_d1_o1_v0.png -> img382_d1_o1_v0.png
# ✅ Renombrado: img383_d1_o1_v0.png -> img383_d1_o1_v0.png
# ✅ Renombrado: img384_d1_o1_v0.png -> img384_d1_o1_v0.png
# ✅ Renombrado: img385_d1_o1_v0.png -> img385_d1_o1_v0.png
# ✅ Renombrado: img386_d1_o1_v0.png -> img386_d1_o1_v0.png
# ✅ Renombrado: img387_d1_o1_v0.png -> img387_d1_o1_v0.png
# ✅ Renombrado: img388_d1_o1_v0.png -> img388_d1_o1_v0.png
# ✅ Renombrado: img389_d1_o1_v0.png -> img389_d1_o1_v0.png
# ✅ Renombrado: img390_d1_o1_v0.png -> img390_d1_o1_v0.png
# ✅ Renombrado: img391_d1_o1_v0.png -> img391_d1_o1_v0.png
# ✅ Renombrado: img392_d4_o2_v2.png -> img392_d4_o2_v2.png
# ✅ Renombrado: img393_d4_o2_v2.png -> img393_d4_o2_v2.png
# ✅ Renombrado: img394_d5_o2_v3.png -> img394_d5_o2_v3.png
# ✅ Renombrado: img395_d4_o4_v0.png -> img395_d4_o4_v0.png
# ✅ Renombrado: img396_d5_o2_v3.png -> img396_d5_o2_v3.png
# ✅ Renombrado: img397_d6_o2_v4.png -> img397_d6_o2_v4.png
# ✅ Renombrado: img398_d4_o4_v0.png -> img398_d4_o4_v0.png
# ✅ Renombrado: img399_d6_o2_v4.png -> img399_d6_o2_v4.png
# ✅ Renombrado: img400_d1_o1_v0.png -> img400_d1_o1_v0.png
# ✅ Renombrado: img401_d4_o3_v1.jpg -> img401_d4_o3_v1.jpg
# ✅ Renombrado: img402_d6_o5_v1.jpg -> img402_d6_o5_v1.jpg
# ✅ Renombrado: img403_d3_o3_v0.jpg -> img403_d3_o3_v0.jpg
# ✅ Renombrado: img404_d5_o5_v0.jpg -> img404_d5_o5_v0.jpg
# ✅ Renombrado: img405_d0_o0_v0.jpg -> img405_d0_o0_v0.jpg
# ✅ Renombrado: img406_d4_o3_v1.jpg -> img406_d4_o3_v1.jpg
# ✅ Renombrado: img407_d2_o2_v0.jpg -> img407_d2_o2_v0.jpg
# ✅ Renombrado: img408_d6_o3_v3.jpg -> img408_d6_o3_v3.jpg
# ✅ Renombrado: img409_d2_o1_v1.jpg -> img409_d2_o1_v1.jpg
# ✅ Renombrado: img410_d2_o1_v1.jpg -> img410_d2_o1_v1.jpg
# ✅ Renombrado: img411_d3_o2_v1.jpg -> img411_d3_o2_v1.jpg
# ✅ Renombrado: img412_d2_o2_v0.jpg -> img412_d2_o2_v0.jpg
# ✅ Renombrado: img413_d2_o2_v0.jpg -> img413_d2_o2_v0.jpg
# ✅ Renombrado: img414_d3_o3_v0.jpg -> img414_d3_o3_v0.jpg
# ✅ Renombrado: img415_d0_o0_v0.jpg -> img415_d0_o0_v0.jpg
# ✅ Renombrado: img416_d7_o7_v0.jpg -> img416_d7_o7_v0.jpg
# ✅ Renombrado: img417_d0_o0_v0.jpg -> img417_d0_o0_v0.jpg
# ✅ Renombrado: img418_d0_o0_v0.jpg -> img418_d0_o0_v0.jpg
# ✅ Renombrado: img419_d6_o2_v4.jpg -> img419_d6_o2_v4.jpg
# ✅ Renombrado: img420_d6_o1_v5.jpg -> img420_d6_o1_v5.jpg
# ✅ Renombrado: img421_d6_o4_v2.jpg -> img421_d6_o4_v2.jpg
# ✅ Renombrado: img422_d0_o0_v0.jpg -> img422_d0_o0_v0.jpg
# ✅ Renombrado: img423_d6_o2_v4.jpg -> img423_d6_o2_v4.jpg
# ✅ Renombrado: img424_d0_o0_v0.jpg -> img424_d0_o0_v0.jpg
# ✅ Renombrado: img425_d0_o0_v0.jpg -> img425_d0_o0_v0.jpg
# ✅ Renombrado: img426_d0_o0_v0.jpg -> img426_d0_o0_v0.jpg
# ✅ Renombrado: img427_d0_o0_v0.jpg -> img427_d0_o0_v0.jpg
# ✅ Renombrado: img428_d0_o0_v0.jpg -> img428_d0_o0_v0.jpg
# ✅ Renombrado: img429_d4_o1_v3.jpg -> img429_d4_o1_v3.jpg
# ✅ Renombrado: img430_d4_o1_v3.jpg -> img430_d4_o1_v3.jpg
# ✅ Renombrado: img431_d6_o3_v3.jpg -> img431_d6_o3_v3.jpg
# ✅ Renombrado: img432_d1_o1_v0.jpg -> img432_d1_o1_v0.jpg
# ✅ Renombrado: img433_d2_o2_v0.jpg -> img433_d2_o2_v0.jpg
# ✅ Renombrado: img434_d0_o0_v0.jpg -> img434_d0_o0_v0.jpg
# ✅ Renombrado: img435_d4_o2_v2.jpg -> img435_d4_o2_v2.jpg
# ✅ Renombrado: img436_d4_o2_v2.jpg -> img436_d4_o2_v2.jpg
# ✅ Renombrado: img437_d3_o3_v0.jpg -> img437_d3_o3_v0.jpg
# ✅ Renombrado: img438_d0_o0_v0.jpg -> img438_d0_o0_v0.jpg
# ✅ Renombrado: img439_d0_o0_v0.jpg -> img439_d0_o0_v0.jpg
# ✅ Renombrado: img440_d0_o0_v0.jpg -> img440_d0_o0_v0.jpg
# ✅ Renombrado: img441_d0_o0_v0.jpg -> img441_d0_o0_v0.jpg
# ✅ Renombrado: img442_d0_o0_v0.jpg -> img442_d0_o0_v0.jpg
# ✅ Renombrado: img443_d2_o1_v1.jpg -> img443_d2_o1_v1.jpg
# ✅ Renombrado: img444_d3_o1_v2.jpg -> img444_d3_o1_v2.jpg
# ✅ Renombrado: img445_d6_o5_v1.jpg -> img445_d6_o5_v1.jpg
# ✅ Renombrado: img446_d3_o1_v2.jpg -> img446_d3_o1_v2.jpg
# ✅ Renombrado: img447_d6_o0_v6.jpg -> img447_d6_o0_v6.jpg
# ✅ Renombrado: img448_d6_o0_v6.jpg -> img448_d6_o0_v6.jpg
# ✅ Renombrado: img449_d0_o0_v0.jpg -> img449_d0_o0_v0.jpg
# ✅ Renombrado: img450_d5_o4_v1.jpg -> img450_d5_o4_v1.jpg
# ✅ Renombrado: img451_d1_o1_v0.jpg -> img451_d1_o1_v0.jpg
# ✅ Renombrado: img452_d0_o0_v0.jpg -> img452_d0_o0_v0.jpg
# ✅ Renombrado: img453_d4_o3_v1.jpg -> img453_d4_o3_v1.jpg
# ✅ Renombrado: img454_d4_o4_v0.jpg -> img454_d4_o4_v0.jpg
# ✅ Renombrado: img455_d1_o1_v0.jpg -> img455_d1_o1_v0.jpg
# ✅ Renombrado: img456_d1_o1_v0.jpg -> img456_d1_o1_v0.jpg
# ✅ Renombrado: img457_d0_o0_v0.jpg -> img457_d0_o0_v0.jpg
# ✅ Renombrado: img458_d3_o3_v0.jpg -> img458_d3_o3_v0.jpg
# ✅ Renombrado: img459_d3_o2_v1.jpg -> img459_d3_o2_v1.jpg
# ✅ Renombrado: img460_d0_o0_v0.jpg -> img460_d0_o0_v0.jpg
# ✅ Renombrado: img461_d4_o3_v1.jpg -> img461_d4_o3_v1.jpg
# ✅ Renombrado: img462_d0_o0_v0.jpg -> img462_d0_o0_v0.jpg
# ✅ Renombrado: img463_d4_o2_v2.jpg -> img463_d4_o2_v2.jpg
# ✅ Renombrado: img464_d0_o0_v0.jpg -> img464_d0_o0_v0.jpg
# ✅ Renombrado: img465_d0_o0_v0.jpg -> img465_d0_o0_v0.jpg
# ✅ Renombrado: img466_d10_o6_v4.png -> img466_d10_o6_v4.png
# ✅ Renombrado: img467_d5_o2_v3.jpg -> img467_d5_o2_v3.jpg
# ✅ Renombrado: img468_d0_o0_v0.jpg -> img468_d0_o0_v0.jpg
# ✅ Renombrado: img469_d3_o1_v2.jpg -> img469_d3_o1_v2.jpg
# ✅ Renombrado: img470_d2_o2_v0.jpg -> img470_d2_o2_v0.jpg
# ✅ Renombrado: img471_d4_o0_v4.jpg -> img471_d4_o0_v4.jpg
# ✅ Renombrado: img472_d6_o0_v6.jpg -> img472_d6_o0_v6.jpg
# ✅ Renombrado: img473_d3_o3_v0.jpg -> img473_d3_o3_v0.jpg
# ✅ Renombrado: img474_d0_o0_v0.jpg -> img474_d0_o0_v0.jpg
# ✅ Renombrado: img475_d3_o2_v1.jpg -> img475_d3_o2_v1.jpg
# ✅ Renombrado: img476_d3_o3_v0.jpg -> img476_d3_o3_v0.jpg
# ✅ Renombrado: img477_d0_o0_v0.jpg -> img477_d0_o0_v0.jpg
# ✅ Renombrado: img478_d4_o1_v3.jpg -> img478_d4_o1_v3.jpg
# ✅ Renombrado: img479_d6_o0_v6.jpg -> img479_d6_o0_v6.jpg
# ✅ Renombrado: img480_d1_o1_v0.jpg -> img480_d1_o1_v0.jpg
# ✅ Renombrado: img481_d6_o2_v4.jpg -> img481_d6_o2_v4.jpg
# ✅ Renombrado: img482_d2_o1_v1.jpg -> img482_d2_o1_v1.jpg
# ✅ Renombrado: img483_d1_o1_v0.jpg -> img483_d1_o1_v0.jpg
# ✅ Renombrado: img484_d6_o2_v4.jpg -> img484_d6_o2_v4.jpg
# ✅ Renombrado: img485_d0_o0_v0.jpg -> img485_d0_o0_v0.jpg
# ✅ Renombrado: img486_d0_o0_v0.jpg -> img486_d0_o0_v0.jpg
# ✅ Renombrado: img487_d0_o0_v0.jpg -> img487_d0_o0_v0.jpg
# ✅ Renombrado: img488_d0_o0_v0.jpg -> img488_d0_o0_v0.jpg
# ✅ Renombrado: img489_d1_o1_v0.png -> img489_d1_o1_v0.png
# ✅ Renombrado: img490_d2_o0_v2.png -> img490_d2_o0_v2.png
# ✅ Renombrado: img491_d1_o1_v0.png -> img491_d1_o1_v0.png
# ✅ Renombrado: img492_d1_o1_v0.png -> img492_d1_o1_v0.png
# ✅ Renombrado: img493_d1_o1_v0.png -> img493_d1_o1_v0.png
# ✅ Renombrado: img494_d2_o2_v0.png -> img494_d2_o2_v0.png
# ✅ Renombrado: img495_d2_o2_v0.png -> img495_d2_o2_v0.png
# ✅ Renombrado: img496_d3_o3_v0.png -> img496_d3_o3_v0.png
# ✅ Renombrado: img497_d4_o3_v1.png -> img497_d4_o3_v1.png
# ✅ Renombrado: img498_d2_o2_v0.png -> img498_d2_o2_v0.png
# ✅ Renombrado: img499_d3_o2_v1.png -> img499_d3_o2_v1.png
# ✅ Renombrado: img500_d6_o0_v6.png -> img500_d6_o0_v6.png
# ✅ Renombrado: img501_d3_o3_v0.png -> img501_d3_o3_v0.png
# ✅ Renombrado: img502_d4_o2_v2.png -> img502_d4_o2_v2.png
# ✅ Renombrado: img503_d4_o4_v0.png -> img503_d4_o4_v0.png
# ✅ Renombrado: img504_d1_o1_v0.png -> img504_d1_o1_v0.png
# ✅ Renombrado: img505_d2_o2_v0.png -> img505_d2_o2_v0.png
# ✅ Renombrado: img506_d2_o2_v0.png -> img506_d2_o2_v0.png
# ✅ Renombrado: img507_d2_o1_v1.png -> img507_d2_o1_v1.png
# ✅ Renombrado: img508_d4_o4_v0.png -> img508_d4_o4_v0.png
# ✅ Renombrado: img509_d3_o3_v0.png -> img509_d3_o3_v0.png
# ✅ Renombrado: img510_d1_o1_v0.png -> img510_d1_o1_v0.png
# ✅ Renombrado: img511_d1_o1_v0.png -> img511_d1_o1_v0.png
# ✅ Renombrado: img512_d1_o1_v0.png -> img512_d1_o1_v0.png
# ✅ Renombrado: img513_d1_o1_v0.png -> img513_d1_o1_v0.png
# ✅ Renombrado: img514_d1_o1_v0.png -> img514_d1_o1_v0.png
# ✅ Renombrado: img515_d1_o1_v0.png -> img515_d1_o1_v0.png
# ✅ Renombrado: img516_d1_o1_v0.png -> img516_d1_o1_v0.png
# ✅ Renombrado: img517_d1_o1_v0.png -> img517_d1_o1_v0.png
# ✅ Renombrado: img518_d1_o1_v0.png -> img518_d1_o1_v0.png
# ✅ Renombrado: img519_d4_o3_v1.png -> img519_d4_o3_v1.png
# ✅ Renombrado: img520_d4_o4_v0.png -> img520_d4_o4_v0.png
# ✅ Renombrado: img521_d4_o4_v0.png -> img521_d4_o4_v0.png
# ✅ Renombrado: img522_d1_o1_v0.png -> img522_d1_o1_v0.png
# ✅ Renombrado: img523_d1_o1_v0.png -> img523_d1_o1_v0.png
# ✅ Renombrado: img524_d1_o1_v0.png -> img524_d1_o1_v0.png
# ✅ Renombrado: img525_d4_o3_v1.png -> img525_d4_o3_v1.png
# ✅ Renombrado: img526_d6_o3_v3.png -> img526_d6_o3_v3.png
# ✅ Renombrado: img527_d4_o3_v1.png -> img527_d4_o3_v1.png
# ✅ Renombrado: img528_d5_o2_v3.png -> img528_d5_o2_v3.png
# ✅ Renombrado: img529_d6_o3_v3.png -> img529_d6_o3_v3.png
# ✅ Renombrado: img530_d4_o2_v2.png -> img530_d4_o2_v2.png
# ✅ Renombrado: img531_d6_o0_v6.png -> img531_d6_o0_v6.png
# ✅ Renombrado: img532_d4_o2_v2.png -> img532_d4_o2_v2.png
# ✅ Renombrado: img533_d6_o0_v6.png -> img533_d6_o0_v6.png
# ✅ Renombrado: img534_d6_o3_v3.png -> img534_d6_o3_v3.png
# ✅ Renombrado: img535_d6_o2_v4.png -> img535_d6_o2_v4.png
# ✅ Renombrado: img536_d6_o2_v4.png -> img536_d6_o2_v4.png
# ✅ Renombrado: img537_d6_o0_v6.png -> img537_d6_o0_v6.png
# ✅ Renombrado: img538_d2_o1_v1.png -> img538_d2_o1_v1.png
# ✅ Renombrado: img539_d3_o2_v1.png -> img539_d3_o2_v1.png
# ✅ Renombrado: img540_d2_o1_v1.png -> img540_d2_o1_v1.png
# ✅ Renombrado: img541_d3_o2_v1.png -> img541_d3_o2_v1.png
# ✅ Renombrado: img542_d5_o2_v3.png -> img542_d5_o2_v3.png
# ✅ Renombrado: img543_d4_o2_v2.png -> img543_d4_o2_v2.png
# ✅ Renombrado: img544_d6_o2_v4.png -> img544_d6_o2_v4.png
# ✅ Renombrado: img545_d6_o1_v5.png -> img545_d6_o1_v5.png
# ✅ Renombrado: img546_d1_o0_v1.png -> img546_d1_o0_v1.png
# ✅ Renombrado: img547_d4_o3_v1.png -> img547_d4_o3_v1.png
# ✅ Renombrado: img548_d4_o3_v1.png -> img548_d4_o3_v1.png
# ✅ Renombrado: img549_d3_o2_v1.png -> img549_d3_o2_v1.png
# ✅ Renombrado: img550_d3_o2_v1.png -> img550_d3_o2_v1.png
# ✅ Renombrado: img551_d2_o2_v0.png -> img551_d2_o2_v0.png
# ✅ Renombrado: img552_d2_o2_v0.png -> img552_d2_o2_v0.png
# ✅ Renombrado: img553_d2_o2_v0.png -> img553_d2_o2_v0.png
# ✅ Renombrado: img554_d4_o2_v2.png -> img554_d4_o2_v2.png
# ✅ Renombrado: img555_d2_o1_v1.png -> img555_d2_o1_v1.png
# ✅ Renombrado: img556_d2_o1_v1.png -> img556_d2_o1_v1.png
# ✅ Renombrado: img557_d2_o1_v1.png -> img557_d2_o1_v1.png
# ✅ Renombrado: img558_d3_o2_v1.png -> img558_d3_o2_v1.png
# ✅ Renombrado: img559_d6_o4_v2.png -> img559_d6_o4_v2.png
# ✅ Renombrado: img560_d6_o3_v3.png -> img560_d6_o3_v3.png
# ✅ Renombrado: img561_d6_o3_v3.png -> img561_d6_o3_v3.png
# ✅ Renombrado: img562_d2_o2_v0.png -> img562_d2_o2_v0.png
# ✅ Renombrado: img563_d1_o1_v0.png -> img563_d1_o1_v0.png
# ✅ Renombrado: img564_d1_o1_v0.png -> img564_d1_o1_v0.png
# ✅ Renombrado: img565_d1_o1_v0.png -> img565_d1_o1_v0.png
# ✅ Renombrado: img566_d1_o1_v0.png -> img566_d1_o1_v0.png
# ✅ Renombrado: img567_d1_o1_v0.png -> img567_d1_o1_v0.png
# ✅ Renombrado: img568_d2_o2_v0.png -> img568_d2_o2_v0.png
# ✅ Renombrado: img569_d1_o1_v0.png -> img569_d1_o1_v0.png
# ✅ Renombrado: img570_d3_o2_v1.png -> img570_d3_o2_v1.png
# ✅ Renombrado: img571_d1_o1_v0.png -> img571_d1_o1_v0.png
# ✅ Renombrado: img572_d6_o2_v4.png -> img572_d6_o2_v4.png
# ✅ Renombrado: img573_d1_o1_v0.png -> img573_d1_o1_v0.png
# ✅ Renombrado: img574_d2_o1_v1.png -> img574_d2_o1_v1.png
# ✅ Renombrado: img575_d1_o1_v0.png -> img575_d1_o1_v0.png
# ✅ Renombrado: img576_d1_o1_v0.png -> img576_d1_o1_v0.png
# ✅ Renombrado: img577_d1_o1_v0.png -> img577_d1_o1_v0.png
# ✅ Renombrado: img578_d2_o2_v0.png -> img578_d2_o2_v0.png
# ✅ Renombrado: img579_d2_o2_v0.png -> img579_d2_o2_v0.png
# ✅ Renombrado: img580_d3_o3_v0.png -> img580_d3_o3_v0.png
# ✅ Renombrado: img581_d4_o4_v0.png -> img581_d4_o4_v0.png
# ✅ Renombrado: img582_d2_o2_v0.png -> img582_d2_o2_v0.png
# ✅ Renombrado: img583_d1_o1_v0.png -> img583_d1_o1_v0.png
# ✅ Renombrado: img584_d1_o1_v0.png -> img584_d1_o1_v0.png
# ✅ Renombrado: img585_d1_o1_v0.png -> img585_d1_o1_v0.png
# ✅ Renombrado: img586_d1_o1_v0.png -> img586_d1_o1_v0.png
# ✅ Renombrado: img587_d2_o2_v0.png -> img587_d2_o2_v0.png
# ✅ Renombrado: img588_d6_o4_v2.png -> img588_d6_o4_v2.png
# ✅ Renombrado: img589_d1_o1_v0.png -> img589_d1_o1_v0.png
# ✅ Renombrado: img590_d4_o3_v1.png -> img590_d4_o3_v1.png
# ✅ Renombrado: img591_d2_o2_v0.png -> img591_d2_o2_v0.png
# ✅ Renombrado: img592_d1_o1_v0.png -> img592_d1_o1_v0.png
# ✅ Renombrado: img593_d0_o0_v0.png -> img593_d0_o0_v0.png
# ✅ Renombrado: img594_d2_o2_v0.png -> img594_d2_o2_v0.png
# ✅ Renombrado: img595_d1_o1_v0.png -> img595_d1_o1_v0.png
# ✅ Renombrado: img596_d2_o2_v0.png -> img596_d2_o2_v0.png
# ✅ Renombrado: img597_d2_o2_v0.png -> img597_d2_o2_v0.png
# ✅ Renombrado: img598_d2_o2_v0.png -> img598_d2_o2_v0.png
# ✅ Renombrado: img599_d1_o1_v0.png -> img599_d1_o1_v0.png
# ✅ Renombrado: img600_d4_o3_v1.png -> img600_d4_o3_v1.png
# ✅ Renombrado: img601_d1_o1_v1.png -> img601_d1_o1_v1.png
# ✅ Renombrado: img602_d0_o0_v0.png -> img602_d0_o0_v0.png
# ✅ Renombrado: img603_d2_o2_v0.png -> img603_d2_o2_v0.png
# ✅ Renombrado: img604_d0_o0_v0.png -> img604_d0_o0_v0.png
# ✅ Renombrado: img605_d3_o3_v0.png -> img605_d3_o3_v0.png
# ✅ Renombrado: img606_d2_o2_v0.png -> img606_d2_o2_v0.png
# ✅ Renombrado: img607_d4_o4_v0.png -> img607_d4_o4_v0.png
# ✅ Renombrado: img608_d5_o4_v1.png -> img608_d5_o4_v1.png
# ✅ Renombrado: img609_d2_o2_v0.png -> img609_d2_o2_v0.png
# ✅ Renombrado: img610_d3_o3_v0.png -> img610_d3_o3_v0.png
# ✅ Renombrado: img611_d4_o4_v0.png -> img611_d4_o4_v0.png
# ✅ Renombrado: img612_d2_o2_v0.png -> img612_d2_o2_v0.png
# ✅ Renombrado: img613_d1_o1_v0.png -> img613_d1_o1_v0.png
# ✅ Renombrado: img614_d3_o3_v0.png -> img614_d3_o3_v0.png
# ✅ Renombrado: img615_d2_o2_v0.png -> img615_d2_o2_v0.png
# ✅ Renombrado: img616_d0_o0_v0.png -> img616_d0_o0_v0.png
# ✅ Renombrado: img617_d0_o0_v0.png -> img617_d0_o0_v0.png
# ✅ Renombrado: img618_d1_o1_v0.png -> img618_d1_o1_v0.png
# ✅ Renombrado: img619_d6_o6_v0.png -> img619_d6_o6_v0.png
# ✅ Renombrado: img620_d2_o2_v0.png -> img620_d2_o2_v0.png
# ✅ Renombrado: img621_d2_o2_v0.png -> img621_d2_o2_v0.png
# ✅ Renombrado: img622_d6_o4_v2.png -> img622_d6_o4_v2.png
# ✅ Renombrado: img623_d4_o3_v1.png -> img623_d4_o3_v1.png
# ✅ Renombrado: img624_d6_o3_v3.png -> img624_d6_o3_v3.png
# ✅ Renombrado: img625_d4_o3_v1.png -> img625_d4_o3_v1.png
# ✅ Renombrado: img626_d4_o3_v1.png -> img626_d4_o3_v1.png
# ✅ Renombrado: img627_d2_o1_v1.png -> img627_d2_o1_v1.png
# ✅ Renombrado: img628_d4_o2_v2.png -> img628_d4_o2_v2.png
# ✅ Renombrado: img629_d4_o2_v2.png -> img629_d4_o2_v2.png
# ✅ Renombrado: img630_d2_o1_v1.png -> img630_d2_o1_v1.png
# ✅ Renombrado: img631_d3_o2_v1.png -> img631_d3_o2_v1.png
# ✅ Renombrado: img632_d3_o2_v1.png -> img632_d3_o2_v1.png
# ✅ Renombrado: img633_d3_o2_v1.png -> img633_d3_o2_v1.png
# ✅ Renombrado: img634_d1_o1_v0.png -> img634_d1_o1_v0.png
# ✅ Renombrado: img635_d2_o2_v0.png -> img635_d2_o2_v0.png
# ✅ Renombrado: img636_d2_o2_v0.png -> img636_d2_o2_v0.png
# ✅ Renombrado: img637_d1_o1_v0.png -> img637_d1_o1_v0.png
# ✅ Renombrado: img638_d3_o2_v1.png -> img638_d3_o2_v1.png
# ✅ Renombrado: img639_d6_o6_v0.png -> img639_d6_o6_v0.png
# ✅ Renombrado: img640_d0_o0_v0.png -> img640_d0_o0_v0.png
# ✅ Renombrado: img641_d1_o1_v0.png -> img641_d1_o1_v0.png
# ✅ Renombrado: img642_d6_o6_v0.png -> img642_d6_o6_v0.png
# ✅ Renombrado: img643_d2_o1_v1.png -> img643_d2_o1_v1.png
# ✅ Renombrado: img644_d1_o1_v0.png -> img644_d1_o1_v0.png
# ✅ Renombrado: img645_d1_o0_v1.png -> img645_d1_o0_v1.png
# ✅ Renombrado: img646_d6_o1_v5.png -> img646_d6_o1_v5.png
# ✅ Renombrado: img647_d6_o0_v6.png -> img647_d6_o0_v6.png
# ✅ Renombrado: img648_d6_o3_v3.png -> img648_d6_o3_v3.png
# ✅ Renombrado: img649_d5_o5_v0.png -> img649_d5_o5_v0.png
# ✅ Renombrado: img650_d4_o4_v0.png -> img650_d4_o4_v0.png
# ✅ Renombrado: img651_d2_o1_v1.png -> img651_d2_o1_v1.png
# ✅ Renombrado: img652_d1_o1_v0.png -> img652_d1_o1_v0.png
# ✅ Renombrado: img653_d1_o1_v0.png -> img653_d1_o1_v0.png
# ✅ Renombrado: img654_d3_o2_v1.png -> img654_d3_o2_v1.png
# ✅ Renombrado: img655_d1_o1_v0.png -> img655_d1_o1_v0.png
# ✅ Renombrado: img656_d3_o1_v2.png -> img656_d3_o1_v2.png
# ✅ Renombrado: img657_d2_o1_v1.png -> img657_d2_o1_v1.png
# ✅ Renombrado: img658_d4_o3_v1.png -> img658_d4_o3_v1.png
# ✅ Renombrado: img659_d4_o2_v2.png -> img659_d4_o2_v2.png
# ✅ Renombrado: img660_d6_o6_v0.png -> img660_d6_o6_v0.png
# ✅ Renombrado: img661_d3_o1_v2.png -> img661_d3_o1_v2.png
# ✅ Renombrado: img662_d4_o4_v0.png -> img662_d4_o4_v0.png
# ✅ Renombrado: img663_d5_o5_v0.png -> img663_d5_o5_v0.png
# ✅ Renombrado: img664_d3_o3_v0.png -> img664_d3_o3_v0.png
# ✅ Renombrado: img665_d2_o1_v1.png -> img665_d2_o1_v1.png
# ✅ Renombrado: img666_d3_o3_v0.png -> img666_d3_o3_v0.png
# ✅ Renombrado: img667_d2_o1_v1.png -> img667_d2_o1_v1.png
# ✅ Renombrado: img668_d1_o0_v1.png -> img668_d1_o0_v1.png
# ✅ Renombrado: img669_d6_o2_v4.png -> img669_d6_o2_v4.png
# ✅ Renombrado: img670_d3_o3_v0.png -> img670_d3_o3_v0.png
# ✅ Renombrado: img671_d6_o0_v6.png -> img671_d6_o0_v6.png
# ✅ Renombrado: img672_d2_o2_v0.png -> img672_d2_o2_v0.png
# ✅ Renombrado: img673_d4_o4_v0.png -> img673_d4_o4_v0.png
# ✅ Renombrado: img674_d6_o3_v3.png -> img674_d6_o3_v3.png
# ✅ Renombrado: img675_d6_o2_v4.png -> img675_d6_o2_v4.png
# ✅ Renombrado: img676_d3_o3_v0.png -> img676_d3_o3_v0.png
# ✅ Renombrado: img677_d3_o2_v1.png -> img677_d3_o2_v1.png
# ✅ Renombrado: img678_d2_o2_v0.png -> img678_d2_o2_v0.png
# ✅ Renombrado: img679_d3_o3_v0.png -> img679_d3_o3_v0.png
# ✅ Renombrado: img680_d2_o2_v0.png -> img680_d2_o2_v0.png
# ✅ Renombrado: img681_d1_o1_v0.png -> img681_d1_o1_v0.png
# ✅ Renombrado: img682_d4_o4_v0.png -> img682_d4_o4_v0.png
# ✅ Renombrado: img683_d1_o1_v0.png -> img683_d1_o1_v0.png
# ✅ Renombrado: img684_d1_o1_v0.png -> img684_d1_o1_v0.png
# ✅ Renombrado: img685_d0_o0_v0.png -> img685_d0_o0_v0.png
# ✅ Renombrado: img686_d2_o2_v0.png -> img686_d2_o2_v0.png
# ✅ Renombrado: img687_d0_o0_v0.png -> img687_d0_o0_v0.png
# ✅ Renombrado: img688_d2_o2_v0.png -> img688_d2_o2_v0.png
# ✅ Renombrado: img689_d5_o5_v0.png -> img689_d5_o5_v0.png
# ✅ Renombrado: img690_d2_o1_v1.png -> img690_d2_o1_v1.png
# ✅ Renombrado: img691_d2_o2_v2.png -> img691_d2_o2_v2.png
# ✅ Renombrado: img692_d5_o5_v0.png -> img692_d5_o5_v0.png
# ✅ Renombrado: img693_d5_o2_v3.png -> img693_d5_o2_v3.png
# ✅ Renombrado: img694_d3_o3_v0.png -> img694_d3_o3_v0.png
# ✅ Renombrado: img695_d3_o3_v0.png -> img695_d3_o3_v0.png
# ✅ Renombrado: img696_d1_o1_v0.png -> img696_d1_o1_v0.png
# ✅ Renombrado: img697_d3_o3_v0.png -> img697_d3_o3_v0.png
# ✅ Renombrado: img698_d1_o1_v0.png -> img698_d1_o1_v0.png
# ✅ Renombrado: img699_d1_o0_v1.png -> img699_d1_o0_v1.png
# ✅ Renombrado: img700_d3_o3_v0.png -> img700_d3_o3_v0.png
# ✅ Renombrado: img701_d2_o2_v0.png -> img701_d2_o2_v0.png
# ✅ Renombrado: img702_d1_o1_v0.png -> img702_d1_o1_v0.png
# ✅ Renombrado: img703_d1_o1_v0.png -> img703_d1_o1_v0.png
# ✅ Renombrado: img704_d3_o3_v0.png -> img704_d3_o3_v0.png
# ✅ Renombrado: img705_d1_o1_v0.png -> img705_d1_o1_v0.png
# ✅ Renombrado: img706_d5_o5_v0.png -> img706_d5_o5_v0.png
# ✅ Renombrado: img707_d6_o5_v1.png -> img707_d6_o5_v1.png
# ✅ Renombrado: img708_d5_o5_v0.png -> img708_d5_o5_v0.png
# ✅ Renombrado: img709_d3_o3_v0.png -> img709_d3_o3_v0.png
# ✅ Renombrado: img710_d1_o1_v0.png -> img710_d1_o1_v0.png
# ✅ Renombrado: img711_d6_o5_v1.png -> img711_d6_o5_v1.png
# ✅ Renombrado: img712_d2_o1_v1.png -> img712_d2_o1_v1.png
# ✅ Renombrado: img713_d3_o3_v0.png -> img713_d3_o3_v0.png
# ✅ Renombrado: img714_d1_o1_v0.png -> img714_d1_o1_v0.png
# ✅ Renombrado: img715_d1_o1_v0.png -> img715_d1_o1_v0.png
# ✅ Renombrado: img716_d1_o1_v0.png -> img716_d1_o1_v0.png
# ✅ Renombrado: img717_d1_o1_v0.png -> img717_d1_o1_v0.png
# ✅ Renombrado: img718_d1_o1_v0.png -> img718_d1_o1_v0.png
# ✅ Renombrado: img719_d6_o6_v0.png -> img719_d6_o6_v0.png
# ✅ Renombrado: img720_d5_o5_v0.png -> img720_d5_o5_v0.png
# ✅ Renombrado: img721_d2_o2_v0.png -> img721_d2_o2_v0.png
# ✅ Renombrado: img723_d2_o2_v0.png -> img723_d2_o2_v0.png
# ✅ Renombrado: img724_d1_o1_v0.png -> img724_d1_o1_v0.png
# ✅ Renombrado: img725_d1_o0_v1.png -> img725_d1_o0_v1.png
# ✅ Renombrado: img726_d4_o4_v0.png -> img726_d4_o4_v0.png
# ✅ Renombrado: img727_d1_o1_v0.png -> img727_d1_o1_v0.png
# ✅ Renombrado: img728_d3_o3_v0.png -> img728_d3_o3_v0.png
# ✅ Renombrado: img729_d1_o1_v0.png -> img729_d1_o1_v0.png
# ✅ Renombrado: img730_d1_o1_v0.png -> img730_d1_o1_v0.png
# ✅ Renombrado: img731_d1_o1_v0.png -> img731_d1_o1_v0.png
# ✅ Renombrado: img732_d3_o3_v0.png -> img732_d3_o3_v0.png
# ✅ Renombrado: img733_d1_o1_v0.png -> img733_d1_o1_v0.png
# ✅ Renombrado: img734_d6_o6_v0.png -> img734_d6_o6_v0.png
# ✅ Renombrado: img735_d1_o1_v0.png -> img735_d1_o1_v0.png
# ✅ Renombrado: img736_d1_o1_v0.png -> img736_d1_o1_v0.png
# ✅ Renombrado: img737_d1_o0_v1.png -> img737_d1_o0_v1.png
# ✅ Renombrado: img738_d4_o4_v0.png -> img738_d4_o4_v0.png
# ✅ Renombrado: img739_d1_o1_v0.png -> img739_d1_o1_v0.png
# ✅ Renombrado: img740_d4_o4_v0.png -> img740_d4_o4_v0.png
# ✅ Renombrado: img741_d4_o3_v1.png -> img741_d4_o3_v1.png
# ✅ Renombrado: img742_d1_o1_v0.png -> img742_d1_o1_v0.png
# ✅ Renombrado: img743_d1_o1_v0.png -> img743_d1_o1_v0.png
# ✅ Renombrado: img744_d2_o2_v0.png -> img744_d2_o2_v0.png
# ✅ Renombrado: img745_d0_o0_v0.png -> img745_d0_o0_v0.png
# ✅ Renombrado: img746_d5_o3_v2.png -> img746_d5_o3_v2.png
# ✅ Renombrado: img747_d6_o6_v0.png -> img747_d6_o6_v0.png
# ✅ Renombrado: img748_d3_o3_v0.png -> img748_d3_o3_v0.png
# ✅ Renombrado: img749_d4_o4_v0.png -> img749_d4_o4_v0.png
# ✅ Renombrado: img750_d2_o2_v0.png -> img750_d2_o2_v0.png
# ✅ Renombrado: img751_d1_o1_v0.png -> img751_d1_o1_v0.png
# ✅ Renombrado: img752_d6_o6_v0.png -> img752_d6_o6_v0.png
# ✅ Renombrado: img753_d5_o5_v0.png -> img753_d5_o5_v0.png
# ✅ Renombrado: img754_d1_o1_v0.png -> img754_d1_o1_v0.png
# ✅ Renombrado: img755_d1_o1_v0.png -> img755_d1_o1_v0.png
# ✅ Renombrado: img756_d1_o1_v0.png -> img756_d1_o1_v0.png
# ✅ Renombrado: img757_d3_o3_v0.png -> img757_d3_o3_v0.png
# ✅ Renombrado: img758_d3_o2_v1.png -> img758_d3_o2_v1.png
# ✅ Renombrado: img759_d1_o1_v0.png -> img759_d1_o1_v0.png
# ✅ Renombrado: img760_d2_o2_v0.png -> img760_d2_o2_v0.png
# ✅ Renombrado: img761_d2_o2_v0.png -> img761_d2_o2_v0.png
# ✅ Renombrado: img762_d3_o3_v0.png -> img762_d3_o3_v0.png
# ✅ Renombrado: img763_d2_o2_v0.png -> img763_d2_o2_v0.png
# ✅ Renombrado: img764_d1_o1_v0.png -> img764_d1_o1_v0.png
# ✅ Renombrado: img765_d1_o1_v0.png -> img765_d1_o1_v0.png
# ✅ Renombrado: img766_d3_o3_v0.png -> img766_d3_o3_v0.png
# ✅ Renombrado: img767_d4_o3_v1.png -> img767_d4_o3_v1.png
# ✅ Renombrado: img768_d2_o2_v0.png -> img768_d2_o2_v0.png
# ✅ Renombrado: img769_d6_o0_v3.png -> img769_d6_o0_v3.png
# ✅ Renombrado: img770_d1_o1_v0.png -> img770_d1_o1_v0.png
# ✅ Renombrado: img771_d3_o1_v2.png -> img771_d3_o1_v2.png
# ✅ Renombrado: img772_d6_o4_v2.png -> img772_d6_o4_v2.png
# ✅ Renombrado: img773_d3_o2_v1.png -> img773_d3_o2_v1.png
# ✅ Renombrado: img774_d4_o3_v1.png -> img774_d4_o3_v1.png
# ✅ Renombrado: img775_d4_o3_v1.png -> img775_d4_o3_v1.png
# ✅ Renombrado: img776_d2_o2_v0.png -> img776_d2_o2_v0.png
# ✅ Renombrado: img777_d4_o1_v3.png -> img777_d4_o1_v3.png
# ✅ Renombrado: img778_d4_o0_v4.png -> img778_d4_o0_v4.png
# ✅ Renombrado: img779_d3_o2_v1.png -> img779_d3_o2_v1.png
# ✅ Renombrado: img780_d6_o2_v4.png -> img780_d6_o2_v4.png
# ✅ Renombrado: img781_d3_o1_v2.png -> img781_d3_o1_v2.png
# ✅ Renombrado: img782_d2_o0_v2.png -> img782_d2_o0_v2.png
# ✅ Renombrado: img783_d0_o0_v0.png -> img783_d0_o0_v0.png
# ✅ Renombrado: img784_d4_o1_v3.png -> img784_d4_o1_v3.png
# ✅ Renombrado: img785_d4_o2_v2.png -> img785_d4_o2_v2.png
# ✅ Renombrado: img786_d2_o1_v1.png -> img786_d2_o1_v1.png
# ✅ Renombrado: img787_d2_o2_v0.png -> img787_d2_o2_v0.png
# ✅ Renombrado: img788_d4_o2_v2.png -> img788_d4_o2_v2.png
# ✅ Renombrado: img789_d4_o2_v2.png -> img789_d4_o2_v2.png
# ✅ Renombrado: img790_d6_o0_v6.png -> img790_d6_o0_v6.png
# ✅ Renombrado: img791_d4_o4_v0.png -> img791_d4_o4_v0.png
# ✅ Renombrado: img792_d1_o1_v0.png -> img792_d1_o1_v0.png
# ✅ Renombrado: img793_d4_o4_v0.png -> img793_d4_o4_v0.png
# ✅ Renombrado: img794_d1_o1_v0.png -> img794_d1_o1_v0.png
# ✅ Renombrado: img795_d0_o0_v0.png -> img795_d0_o0_v0.png
# ✅ Renombrado: img796_d3_o3_v0.png -> img796_d3_o3_v0.png
# ✅ Renombrado: img797_d1_o1_v0.png -> img797_d1_o1_v0.png
# ✅ Renombrado: img798_d1_o1_v0.png -> img798_d1_o1_v0.png
# ✅ Renombrado: img799_d1_o1_v0.png -> img799_d1_o1_v0.png
# ✅ Renombrado: img800_d2_o2_v0.png -> img800_d2_o2_v0.png
# ✅ Renombrado: img801_d1_o1_v0.png -> img801_d1_o1_v0.png
# ✅ Renombrado: img802_d2_o2_v0.png -> img802_d2_o2_v0.png
# ✅ Renombrado: img803_d2_o2_v0.png -> img803_d2_o2_v0.png
# ✅ Renombrado: img804_d2_o2_v0.png -> img804_d2_o2_v0.png
# ✅ Renombrado: img805_d2_o2_v0.png -> img805_d2_o2_v0.png
# ✅ Renombrado: img806_d1_o1_v0.png -> img806_d1_o1_v0.png
# ✅ Renombrado: img807_d1_o1_v0.png -> img807_d1_o1_v0.png
# ✅ Renombrado: img808_d4_o4_v0.png -> img808_d4_o4_v0.png
# ✅ Renombrado: img809_d2_o2_v0.png -> img809_d2_o2_v0.png
# ✅ Renombrado: img810_d3_o3_v3.png -> img810_d3_o3_v3.png
# ✅ Renombrado: img811_d5_o4_v1.png -> img811_d5_o4_v1.png
# ✅ Renombrado: img812_d1_o1_v0.png -> img812_d1_o1_v0.png
# ✅ Renombrado: img813_d2_o2_v0.png -> img813_d2_o2_v0.png
# ✅ Renombrado: img814_d2_o2_v0.png -> img814_d2_o2_v0.png
# ✅ Renombrado: img815_d6_o2_v4.png -> img815_d6_o2_v4.png
# ✅ Renombrado: img816_d2_o2_v0.png -> img816_d2_o2_v0.png
# ✅ Renombrado: img817_d6_o2_v4.png -> img817_d6_o2_v4.png
# ✅ Renombrado: img818_d6_o2_v4.png -> img818_d6_o2_v4.png
# ✅ Renombrado: img819_d4_o3_v1.png -> img819_d4_o3_v1.png
# ✅ Renombrado: img820_d6_o2_v4.png -> img820_d6_o2_v4.png
# ✅ Renombrado: img821_d6_o0_v6.png -> img821_d6_o0_v6.png
# ✅ Renombrado: img822_d4_o0_v4.png -> img822_d4_o0_v4.png
# ✅ Renombrado: img823_d5_o2_v3.png -> img823_d5_o2_v3.png
# ✅ Renombrado: img824_d3_o3_v0.png -> img824_d3_o3_v0.png
# ✅ Renombrado: img825_d2_o2_v0.png -> img825_d2_o2_v0.png
# ✅ Renombrado: img826_d1_o0_v1.png -> img826_d1_o0_v1.png
# ✅ Renombrado: img827_d1_o1_v0.png -> img827_d1_o1_v0.png
# ✅ Renombrado: img828_d4_o2_v2.png -> img828_d4_o2_v2.png
# ✅ Renombrado: img829_d2_o1_v1.png -> img829_d2_o1_v1.png
# ✅ Renombrado: img830_d3_o2_v1.png -> img830_d3_o2_v1.png
# ✅ Renombrado: img831_d4_o4_v0.png -> img831_d4_o4_v0.png
# ✅ Renombrado: img832_d1_o1_v0.png -> img832_d1_o1_v0.png
# ✅ Renombrado: img833_d2_o2_v0.png -> img833_d2_o2_v0.png
# ✅ Renombrado: img834_d3_o3_v1.png -> img834_d3_o3_v1.png
# ✅ Renombrado: img835_d3_o3_v0.png -> img835_d3_o3_v0.png
# ✅ Renombrado: img836_d1_o1_v0.png -> img836_d1_o1_v0.png
